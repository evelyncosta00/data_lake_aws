# %%
# !mkdir data
# Out:
# J� existe uma subpasta ou um arquivo data.

# %%
import pandas as pd
import urllib.request

# %%
def extract_data(url, filename):
    try:
        urllib.request.urlretrieve(url, filename)

    except Exception as e:
        print (e)

# %%
#extract_data("https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/c9509ab4-6f6d-4b97-979a-0cf2a10c922b/download/tmphrybkxuh.csv","data\data_2015.csv")
#extract_data(r'https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/b7ea6b1b-3ca4-4c5b-9713-6dc1db52379a/download/tmpzxzxeqfb.csv',"data\data_2016.csv")
#extract_data(r'https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/30022137-709d-465e-baae-ca155b51927d/download/tmpzccn8u4q.csv',"data\data_2017.csv")
#extract_data(r'https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/2be28d90-3a90-4af1-a3f6-f28c1e25880a/download/tmp7602cia8.csv',"data\data_2018.csv")
#extract_data(r'https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/ea2e4696-4a2d-429c-9807-d02eb92e0222/download/tmpcje3ep_w.csv',"data\data_2019.csv")
#extract_data(r'https://data.boston.gov/dataset/8048697b-ad64-4bfc-b090-ee00169f2323/resource/6ff6a6fd-3141-4440-a880-6f60a37fe789/download/tmpcv_10m2s.csv',"data\data_2020.csv")

# %%
#criando lista para o dicionario
arquivos = [
"data\data_2015.csv",
"data\data_2016.csv",
"data\data_2017.csv",
"data\data_2018.csv",
"data\data_2019.csv",
"data\data_2020.csv"    
]
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:7: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Unip\AppData\Local\Temp\ipykernel_53184\460254141.py:3: SyntaxWarning: invalid escape sequence '\d'
#   "data\data_2015.csv",
# C:\Users\Unip\AppData\Local\Temp\ipykernel_53184\460254141.py:4: SyntaxWarning: invalid escape sequence '\d'
#   "data\data_2016.csv",
# ...

# %%
dfs = {}

# %%
#função split para extrair o ano do arquivo (a extração começa do "_" e vai até o ".")
for arquivo in arquivos:
    ano = arquivo.split("_")[-1].split(".")[0]
    dfs[ano] = pd.read_csv(arquivo)
# Out:
# C:\Users\Unip\AppData\Local\Temp\ipykernel_53184\383341722.py:4: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs[ano] = pd.read_csv(arquivo)
# C:\Users\Unip\AppData\Local\Temp\ipykernel_53184\383341722.py:4: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs[ano] = pd.read_csv(arquivo)
# C:\Users\Unip\AppData\Local\Temp\ipykernel_53184\383341722.py:4: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs[ano] = pd.read_csv(arquivo)
# C:\Users\Unip\AppData\Local\Temp\ipykernel_53184\383341722.py:4: DtypeWarning: Columns (13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs[ano] = pd.read_csv(arquivo)
# C:\Users\Unip\AppData\Local\Temp\ipykernel_53184\383341722.py:4: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
dfs["2019"].head()
# Out:
#    case_enquiry_id              open_dt        sla_target_dt  \
# 0     101002767874  2019-01-01 00:03:00  2019-01-03 03:30:00
# 1     101002767875  2019-01-01 00:17:00                  NaN
# 2     101002767877  2019-01-01 00:31:51  2019-01-03 03:30:00
# 3     101002767878  2019-01-01 00:42:00                  NaN
# 4     101002767879  2019-01-01 01:09:12  2019-01-03 03:30:00
#
#              closed_dt on_time case_status  \
# 0  2019-01-01 02:59:43  ONTIME      Closed
# 1  2019-11-24 08:48:34  ONTIME      Closed
# 2  2019-01-01 21:27:40  ONTIME      Closed
# 3  2019-05-17 08:33:13  ONTIME      Closed
# 4  2019-01-01 21:28:11  ONTIME      Closed
#
#                                       closure_reason  \
# 0  Case Closed. Closed date : 2019-01-01 07:59:43...
# 1  Case Closed. Closed date : 2019-11-24 13:48:34...
# 2  Case Closed. Closed date : 2019-01-02 02:27:40...
# 3  Case Closed. Closed date : 2019-05-17 12:33:13...
# 4  Case Closed. Closed date : 2019-01-02 02:28:11...
#
# ...

# %% [markdown]
# # Criando conexão com o S3

# %%
# !pip install boto3

# %%
import boto3 

aws_access_key_id = "aws_secret_access_key"
aws_secret_access_key = "eTo9dnNenfAVwcjXCsvZLGZf1kuzQGcTz1KcZ+cp" 
region_name = "sa-east-1"

boto3.setup_default_session(
    aws_access_key_id = aws_access_key_id,
    aws_secret_access_key = aws_secret_access_key,
    region_name = region_name,
)

s3 - boto3.clien(s3)
